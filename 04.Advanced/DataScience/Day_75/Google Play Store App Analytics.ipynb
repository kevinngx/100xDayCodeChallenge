# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape # 10,841 rows, 12 columns
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.sample(n=5)
# Out:
#                                                     App            Category  \
# 2540                        Treadmill Workouts Free (P)  HEALTH_AND_FITNESS
# 8400  comico Popular Original Cartoon Updated Everyd...              COMICS
# 778                           Wallpapers Volvo FH Truck     PERSONALIZATION
# 670   Axe Throw: Flip Champ Axes Champion Throwing G...                GAME
# 7751                                       PJ Masks: HQ              FAMILY
#
#       Rating  Reviews  Size_MBs   Installs  Type Price Content_Rating  \
# 2540    3.30       10      3.30      1,000  Free     0       Everyone
# 8400    3.20    93965     15.00  5,000,000  Free     0           Teen
# 778     4.20        4     14.00        100  Free     0           Teen
# 670      NaN        1     13.00         50  Free     0       Everyone
# 7751    4.10    13731     55.00  1,000,000  Free     0       Everyone
#
#                                 Genres   Last_Updated   Android_Ver
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(columns=['Last_Updated', 'Android_Ver'], inplace=True)

# %%
df_apps.sample(n=5)
# Out:
#                                                     App            Category  \
# 4298          Fitness Dance for Zum.ba Workout Exercise  HEALTH_AND_FITNESS
# 6463                             B-Messenger Video Chat              SOCIAL
# 8475  Phone X Launcher, OS 11 iLauncher & Control Ce...               TOOLS
# 6288          Lovely Cute Pink Kitty Cat Keyboard Theme     PERSONALIZATION
# 8364                                    Note Everything        PRODUCTIVITY
#
#       Rating  Reviews  Size_MBs   Installs  Type Price Content_Rating  \
# 4298    4.20      287     12.00     50,000  Free     0       Everyone
# 6463    4.10    12495     19.00  1,000,000  Free     0     Mature 17+
# 8475    4.20    54063     16.00  5,000,000  Free     0       Everyone
# 6288    4.30     2267      7.20    500,000  Free     0       Everyone
# 8364    4.40    57033      4.00  5,000,000  Free     0       Everyone
#
#                 Genres
# 4298  Health & Fitness
# 6463            Social
# ...

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
nan_rows=df_apps[df_apps.Rating.isna()]
print(nan_rows.shape)
nan_rows.head()
# Out:
# (1474, 10)
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business

# %%
df_apps.dropna(inplace=True)
df_apps.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps[df_apps.duplicated()]
# Out:
#                                               App            Category  Rating  \
# 946                        420 BZ Budeze Delivery             MEDICAL    5.00
# 1133                                  MouseMingle              DATING    2.70
# 1196   Cardiac diagnosis (heart rate, arrhythmia)             MEDICAL    4.40
# 1231                                 Sway Medical             MEDICAL    5.00
# 1247               Chat Kids - Chat Room For Kids              DATING    4.70
# ...                                           ...                 ...     ...
# 10802               Skype - free IM & video calls       COMMUNICATION    4.10
# 10809                                   Instagram              SOCIAL    4.50
# 10826                                Google Drive        PRODUCTIVITY    4.40
# 10832                                 Google News  NEWS_AND_MAGAZINES    3.90
# 10839                              Subway Surfers                GAME    4.50
#
# ...

# %%
df_apps[df_apps.duplicated()][df_apps[df_apps.duplicated()].App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10809     0           Teen  Social

# %%
df_apps[df_apps.App == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_apps.drop_duplicates(inplace=True)

# %%
df_apps[df_apps.App == 'Instagram'] # This does not remove all of the duplicates as there are variations in the # of reviews
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_apps.drop_duplicates(subset=['App', 'Type', 'Price'], inplace=True) # To resolve this we specify the columns over which we want to enforce uniqueness (think primary keys)

# %%
df_apps[df_apps.App == 'Instagram'] # We should now only have one result for Instagram
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps.sample(n=5)
# Out:
#                         App            Category  Rating  Reviews  Size_MBs  \
# 9616           Bullet Force                GAME    4.50   634159     58.00
# 3641                 CF cal               TOOLS    4.30      123      2.90
# 9531           Dinosaur War              FAMILY    4.30   157997     27.00
# 10386            slither.io                GAME    4.40  5234162     36.00
# 7966   Market Update Helper  LIBRARIES_AND_DEMO    4.10    20145      0.01
#
#           Installs  Type Price Content_Rating            Genres
# 9616    10,000,000  Free     0           Teen            Action
# 3641        10,000  Free     0       Everyone             Tools
# 9531    10,000,000  Free     0       Everyone        Simulation
# 10386  100,000,000  Free     0       Everyone            Action
# 7966     1,000,000  Free     0       Everyone  Libraries & Demo

# %%
df_apps[df_apps.Rating == df_apps.Rating.max()] # Problem here is that many apps have the max rating of '5' but vary in the number of reviews. A 5 star result is more achievable for apps with lower review
# Out:
#                                                    App   Category  Rating  \
# 21                                 KBA-EZ Health Guide    MEDICAL    5.00
# 28                                            Ra Ga Ba       GAME    5.00
# 47                                             Mu.F.O.       GAME    5.00
# 82                                    Brick Breaker BR       GAME    5.00
# 99     Anatomy & Physiology Vocabulary Exam Review App    MEDICAL    5.00
# ...                                                ...        ...     ...
# 2680                               Florida Wildflowers     FAMILY    5.00
# 2750  Superheroes, Marvel, DC, Comics, TV, Movies News     COMICS    5.00
# 3030           CL Keyboard - Myanmar Keyboard (No Ads)      TOOLS    5.00
# 3115                                        Oración CX  LIFESTYLE    5.00
# 4058                          Ek Bander Ne Kholi Dukan     FAMILY    5.00
#
#       Reviews  Size_MBs Installs  Type  Price Content_Rating         Genres
# ...

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps.sort_values('Size_MBs', ascending=False).head()
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 10687          Hungry Shark Evolution                GAME    4.50  6074334
# 9943            Miami crime simulator                GAME    4.00   254518
# 9944     Gangster Town: Vice District              FAMILY    4.30    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
#
#        Size_MBs     Installs  Type Price Content_Rating  \
# 9942     100.00   10,000,000  Free     0       Everyone
# 10687    100.00  100,000,000  Free     0           Teen
# 9943     100.00   10,000,000  Free     0     Mature 17+
# 9944     100.00   10,000,000  Free     0     Mature 17+
# 3144     100.00        5,000  Free     0       Everyone
#
#                        Genres
# 9942   Lifestyle;Pretend Play
# 10687                  Arcade
# 9943                   Action
# 9944               Simulation
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps.sort_values('Reviews', ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10806                                          Instagram              SOCIAL
# 10784           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10835                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10584                                       Clash Royale                GAME
# 10763                                   Candy Crush Saga                GAME
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
import matplotlib.pyplot as plt
import plotly.express as px

# %%
ratings = df_apps.Content_Rating.value_counts()

# %%
ratings
# Out:
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
fig = px.pie(labels=ratings.index, 
             values=ratings.values, 
             names=ratings.index,
             title="Content Rating"
             )
fig.update_traces(textposition='outside', textinfo="percent+label")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
df_apps.sample()
# Out:
#                                  App            Category  Rating  Reviews  \
# 3398  DW Amharic by AudioNow Digital  NEWS_AND_MAGAZINES    4.50      322
#
#       Size_MBs Installs  Type Price Content_Rating            Genres
# 3398     31.00   10,000  Free     0       Everyone  News & Magazines

# %%
df_apps.dtypes # Installs column is of type 'object'
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size_MBs          float64
# Installs           object
# Type               object
# Price              object
# Content_Rating     object
# Genres             object
# dtype: object

# %%
# Step 1 remove ","
df_apps.Installs = df_apps.Installs.str.replace(r'\D', '')
df_apps.sample(n=10)
# Out:
# <ipython-input-28-ea098b473ae6>:2: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#                                 App             Category  Rating  Reviews  \
# 5804  KDRAMA Amino for K-Drama Fans               SOCIAL    4.60     4046
# 7578                   Video Status        VIDEO_PLAYERS    4.30     6685
# 2190                         FG VOC             BUSINESS    4.80        6
# 2360              AE Fishing Hunter                 GAME    4.40       14
# 3968                         Mali J               SOCIAL    3.20      185
# 2325  Invasive Alien Species Europe               FAMILY    4.50       13
# 6379                             ci               FAMILY    3.00     1691
# 657          DX Glow - Clock Widget      PERSONALIZATION    4.40        5
# 6304        ePN Cashback AliExpress             SHOPPING    4.40    19212
# 4854               Discovery Insure  MAPS_AND_NAVIGATION    2.80     1911
#
# ...

# %%
# Step 2 convert to numeric
df_apps.Installs = pd.to_numeric(df_apps.Installs)
df_apps.sample(n=10)
# Out:
#                                           App   Category  Rating  Reviews  \
# 9691                       Amazon for Tablets   SHOPPING    4.00   141613
# 4099            Tunisian Dinar: Exchange rate    FINANCE    4.50      625
# 3578                             CE on the go      TOOLS    4.40       79
# 1505                               CP Channel     FAMILY    4.60        7
# 5778             Sight Words Pre-K to Grade-3     FAMILY    4.40     1185
# 6346                           Dungeon Keeper     FAMILY    4.00    69574
# 6677              Udacity - Lifelong Learning  EDUCATION    4.30    22384
# 8643           Evil Apples: A Dirty Card Game       GAME    4.30   137696
# 7776                      Fruit Ninja Classic       GAME    4.30    85468
# 8166  Casual Dating & Adult Singles - Joyride     DATING    4.50    61637
#
#       Size_MBs  Installs  Type  Price Content_Rating                 Genres
# 9691     22.00  10000000  Free      0           Teen               Shopping
# ...

# %%
df_apps.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int64
# Size_MBs          float64
# Installs            int64
# Type               object
# Price              object
# Content_Rating     object
# Genres             object
# dtype: object

# %%
df_apps[df_apps.Installs == 1000000000]
# Out:
#                                             App             Category  Rating  \
# 10783                         Google Play Books  BOOKS_AND_REFERENCE    3.90
# 10784  Messenger – Text and Video Chat for Free        COMMUNICATION    4.00
# 10785                        WhatsApp Messenger        COMMUNICATION    4.40
# 10786              Google Chrome: Fast & Secure        COMMUNICATION    4.30
# 10787                                     Gmail        COMMUNICATION    4.30
# 10788                                  Hangouts        COMMUNICATION    4.00
# 10792             Skype - free IM & video calls        COMMUNICATION    4.10
# 10803                         Google Play Games        ENTERTAINMENT    4.30
# 10805                                  Facebook               SOCIAL    4.10
# 10806                                 Instagram               SOCIAL    4.50
# 10807                                   Google+               SOCIAL    4.20
# ...

# %%
df_apps[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          303
# 500          199
# 1000         698
# 5000         425
# 10000        988
# 50000        457
# 100000      1096
# 500000       504
# 1000000     1417
# 5000000      607
# 10000000     933
# 50000000     202
# 100000000    189
# 500000000     24
# 1000000000    20

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps.Price = df_apps.Price.str.replace(r'$', '')
df_apps.Price = df_apps.Price.str.replace(r'.', '')
# Out:
# <ipython-input-33-3434df0849d8>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# <ipython-input-33-3434df0849d8>:2: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_apps.Price = pd.to_numeric(df_apps.Price)

# %%
df_apps = df_apps[df_apps.Price < 250]

# %%
df_apps.sort_values('Price', ascending=False).head(10)
# Out:
#                                  App         Category  Rating  Reviews  \
# 1868           Bo's Dinnertime Story           FAMILY    4.30        6
# 1996              Bo's Bedtime Story           FAMILY    4.20       13
# 1373  Asiimov Skin - CS GO Icon Pack  PERSONALIZATION    4.60       26
# 4086       Detect-O-Gromit (D.O.G 2)           FAMILY    3.80       45
# 5104                     BusyBox Pro            TOOLS    4.70     8114
# 3483   Alarmy (Sleep If U Can) - Pro        LIFESTYLE    4.80    10249
# 5928                ADWLauncher 1 EX  PERSONALIZATION    4.30    28728
# 248                     The DG Buddy         BUSINESS    3.70        3
# 2077                    AV Tools Pro            TOOLS    4.30       35
# 2831                Visual Anatomy 2          MEDICAL    4.40      576
#
#       Size_MBs  Installs  Type  Price Content_Rating                  Genres
# 1868     33.00      1000  Paid    249       Everyone  Education;Pretend Play
# ...

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps['Revenue_Estimate'] = df_apps.Installs.mul(df_apps.Price)
df_apps.sort_values('Revenue_Estimate', ascending=False)[:10]
# Out:
#                                                     App         Category  \
# 8825                                      Hitman Sniper             GAME
# 6496                              Beautiful Widgets Pro  PERSONALIZATION
# 7988                                  Where's My Water?           FAMILY
# 7563                                         True Skate           SPORTS
# 5928                                   ADWLauncher 1 EX  PERSONALIZATION
# 6429                               CamScanner (License)     PRODUCTIVITY
# 6364                          Assassin's Creed Identity             GAME
# 7957  League of Stickman 2018- Ninja Arena PVP(Dream...             GAME
# 7691                               Infinity Dungeon VIP           FAMILY
# 7776                                Fruit Ninja Classic             GAME
#
#       Rating  Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 8825    4.60   408292     29.00  10000000  Paid     99     Mature 17+
# ...

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
df_apps.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 28                                         Ra Ga Ba     GAME    5.00        2
# 47                                          Mu.F.O.     GAME    5.00        2
# 82                                 Brick Breaker BR     GAME    5.00        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#     Size_MBs  Installs  Type  Price Content_Rating   Genres  Revenue_Estimate
# 21     25.00         1  Free      0       Everyone  Medical                 0
# 28     20.00         1  Paid    149       Everyone   Arcade               149
# 47     16.00         1  Paid     99       Everyone   Arcade                99
# 82     19.00         5  Free      0       Everyone   Arcade                 0
# 99      4.60         5  Free      0       Everyone  Medical                 0

# %%
num_apps = df_apps.Category.value_counts()[:10]

# %%
num_apps
# Out:
# FAMILY             1500
# GAME                869
# TOOLS               682
# FINANCE             290
# PERSONALIZATION     289
# LIFESTYLE           289
# PRODUCTIVITY        288
# BUSINESS            254
# PHOTOGRAPHY         252
# SPORTS              247
# Name: Category, dtype: int64

# %%
fig = px.bar(x=num_apps.index, y=num_apps.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
downloads = df_apps.groupby('Category').agg({'Installs':pd.Series.sum})

# %%
top_downloads = downloads.sort_values('Installs', ascending=False)
top_downloads
# Out:
#                         Installs
# Category
# GAME                 13853852917
# COMMUNICATION        11037904530
# TOOLS                 8098182040
# PRODUCTIVITY          5787211380
# SOCIAL                5487841475
# PHOTOGRAPHY           4647425110
# FAMILY                4421097130
# VIDEO_PLAYERS         3916847200
# TRAVEL_AND_LOCAL      2894737300
# NEWS_AND_MAGAZINES    2369110150
# ENTERTAINMENT         2113460000
# BOOKS_AND_REFERENCE   1665770555
# PERSONALIZATION       1532024930
# SHOPPING              1400321540
# HEALTH_AND_FITNESS    1133634220
# SPORTS                1096211665
# BUSINESS               691805470
# MAPS_AND_NAVIGATION    503157460
# LIFESTYLE              502588110
# FINANCE                455127800
# WEATHER                360285500
# EDUCATION              352250000
# FOOD_AND_DRINK         211617750
# DATING                 140901310
# ART_AND_DESIGN         114233100
# HOUSE_AND_HOME          97082000
# AUTO_AND_VEHICLES       53129800
# ...

# %%
fig = px.bar(x=top_downloads.Installs, y=top_downloads.index)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
app_count = df_apps.groupby('Category').agg({'App':pd.Series.count})
installation_sum = df_apps.groupby('Category').agg({'Installs':pd.Series.sum})
concentration = pd.merge(app_count, installation_sum, on='Category', how='inner')

# %%
concentration.shape
# Out:
# (33, 2)

# %%
concentration.head(3)
# Out:
#                    App   Installs
# Category
# ART_AND_DESIGN      61  114233100
# AUTO_AND_VEHICLES   73   53129800
# BEAUTY              42   26916200

# %%
scatter = px.scatter(concentration,
                     x='App',
                     y='Installs',
                     title='Category Concentration',
                     size='App',
                     color='Installs',
                     hover_name=concentration.index)

scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)",
                      yaxis_title="Installs",
                      yaxis=dict(type='log'))

scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
len(df_apps.Genres.unique())
# Out:
# 113

# %%
stack = df_apps.Genres.str.split(';', expand=True).stack()

# %%
len(stack.value_counts())
# Out:
# 53

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
num_genres = stack.value_counts()

# %%
stack
# Out:
# 21     0                    Medical
# 28     0                     Arcade
# 47     0                     Arcade
# 82     0                     Arcade
# 99     0                    Medical
#                      ...
# 10824  0               Productivity
# 10828  0    Video Players & Editors
# 10829  0    Video Players & Editors
# 10831  0           News & Magazines
# 10835  0                     Arcade
# Length: 8151, dtype: object

# %%
num_genres
# Out:
# Tools                      682
# Education                  546
# Entertainment              495
# Finance                    290
# Lifestyle                  290
# Action                     289
# Personalization            289
# Productivity               288
# Sports                     255
# Business                   254
# Photography                252
# Communication              247
# Medical                    237
# Health & Fitness           237
# Casual                     209
# News & Magazines           203
# Social                     203
# Simulation                 193
# Travel & Local             181
# Arcade                     181
# Shopping                   179
# Books & Reference          165
# Video Players & Editors    149
# Dating                     131
# Maps & Navigation          115
# Puzzle                     115
# Racing                     100
# Food & Drink                92
# Role Playing                90
# Educational                 84
# ...

# %%
fig = px.bar(x=num_genres.index[:15], y=num_genres.values[:15],
             title='Top Genres',
             hover_name=num_genres.index[:15],
             color=num_genres.values[:15],
             color_continuous_scale='Agsunset')

fig.update_layout(xaxis_title='Genre',
                  yaxis_title='Number of Apps',
                  coloraxis_showscale=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
df_apps.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL    5.00        4
# 28                                         Ra Ga Ba     GAME    5.00        2
# 47                                          Mu.F.O.     GAME    5.00        2
# 82                                 Brick Breaker BR     GAME    5.00        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL    5.00        1
#
#     Size_MBs  Installs  Type  Price Content_Rating   Genres  Revenue_Estimate
# 21     25.00         1  Free      0       Everyone  Medical                 0
# 28     20.00         1  Paid    149       Everyone   Arcade               149
# 47     16.00         1  Paid     99       Everyone   Arcade                99
# 82     19.00         5  Free      0       Everyone   Arcade                 0
# 99      4.60         5  Free      0       Everyone  Medical                 0

# %%
df_free_vs_paid = df_apps.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   58
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %%
fig = px.bar(df_free_vs_paid,
               x='Category',
               y='App',
               title='Free vs Paid Apps by Category',
               color='Type',
               barmode='group')

fig.update_layout(xaxis_title='Category',
                  yaxis_title='Number of Apps',
                  xaxis={'categoryorder':'total descending'},
                  coloraxis_showscale=False,)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box_plot = px.box(df_apps,
               x='Type',
               y='Installs',
               notched=True,
               points='all',
               title='How Many Downloads are Paid Apps Giving Up?',
               color='Type',)

box_plot.update_layout(yaxis=dict(type='log'))

box_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
box_plot = px.box(df_apps[df_apps['Type']=='Paid'],
               x='Category',
               y='Revenue_Estimate',
               title='How Much can Paid Apps Earn?',)

# box_plot.update_layout(yaxis=dict(type='log'))
box_plot.update_layout(xaxis_title='Category',
                  yaxis_title='Paid App Ballpark Revenue',
                  xaxis={'categoryorder':'min ascending'},
                  yaxis=dict(type='log'))

box_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.
